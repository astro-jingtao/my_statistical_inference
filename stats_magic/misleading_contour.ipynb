# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import powerlaw, laplace
from asa.plot_methods import plot_contour, plot_trend

# %%
x = powerlaw.rvs(a=0.3, size=100000)
plt.hist(x)
# Out:
# (array([50128., 11635.,  7966.,  6276.,  5299.,  4532.,  4121.,  3612.,
#          3320.,  3111.]),
#  array([1.21459036e-17, 9.99996114e-02, 1.99999223e-01, 2.99998834e-01,
#         3.99998446e-01, 4.99998057e-01, 5.99997669e-01, 6.99997280e-01,
#         7.99996892e-01, 8.99996503e-01, 9.99996114e-01]),
#  <BarContainer object of 10 artists>)

# %%
y = laplace.rvs(size=100000)
plt.hist(y)
# Out:
# (array([3.0000e+00, 3.1000e+01, 2.6100e+02, 2.5490e+03, 2.3887e+04,
#         6.3425e+04, 8.8030e+03, 9.2900e+02, 1.0600e+02, 6.0000e+00]),
#  array([-11.87771413,  -9.62780852,  -7.37790292,  -5.12799731,
#          -2.8780917 ,  -0.6281861 ,   1.62171951,   3.87162511,
#           6.12153072,   8.37143632,  10.62134193]),
#  <BarContainer object of 10 artists>)

# %%
plot_contour(x, y, range=[[0, 1], [-3, 3]], bins=30, kde_smooth=True)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
plot_contour(x, y, range=[[0, 1], [-3, 3]], bins=30, kde_smooth=True)
plot_trend(x,
           y,
           plot_kwargs={'color': 'blue'},
           plot_scatter_kwargs={'color': 'blue'},
           ifscatter=True)
