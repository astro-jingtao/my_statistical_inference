# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append('..')
import matplotlib.pyplot as plt

# %%
from tools.text_point_cloud import generate_text_point_cloud

# %%
x, y = generate_text_point_cloud(
    'THU', '/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf', jitter_amount=1)

# %%
plt.scatter(x, y)

# %%
x, y = generate_text_point_cloud(
    '清华',
    '/usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc',
    jitter_amount=1)

# %%
plt.scatter(x, y)
